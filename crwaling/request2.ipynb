# %%
# conda install selenium

# %%
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
url = "http://localhost:8080/en3.jsp"
driver = webdriver.Chrome()
driver.get(url)
print(driver.page_source)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 3
#       1 import requests
#       2 from selenium import webdriver
# ----> 3 from bs4 import BeautifulSoup
#       4 url = "http://localhost:8080/en3.jsp"
#       5 driver = webdriver.Chrome()
#
# ModuleNotFoundError: No module named 'bs4'

# %%
conda install BeautifulSoup
# Out:
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed
#
# Note: you may need to restart the kernel to use updated packages.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - beautifulsoup
#
# Current channels:
#
#   - defaults
#   - https://repo.anaconda.com/pkgs/main
#   - https://repo.anaconda.com/pkgs/r
#   - https://repo.anaconda.com/pkgs/msys2
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
a = driver.find_element(By.ID, 'target')
print(a.accessible_name)
a.click()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a = driver.find_element(By.ID, 'target')
#       2 print(a.accessible_name)
#       3 a.click()
#
# NameError: name 'By' is not defined

# %%
dom = BeautifulSoup(driver.page_source, 'lxml')
print(dom.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dom = BeautifulSoup(driver.page_source, 'lxml')
#       2 print(dom.text)
#
# NameError: name 'BeautifulSoup' is not defined
